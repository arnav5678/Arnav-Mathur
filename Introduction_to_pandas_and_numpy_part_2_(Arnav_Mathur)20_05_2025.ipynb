# %%
# Introduction to pandas ----->
# Pandas is an open-source libraray that is used for handle data manipulations

# %%
# Data Structure of pandas
# (1) Series
# (2) DataFrame

# %%
# (1) Series ------> It is one dimensional array and it shows only values not column name.

# %%
import pandas as pd

# %%
a = pd.Series([1,233,67,90])
a
# Out:
# 0      1
# 1    233
# 2     67
# 3     90
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
# (2) DataFrame -----> It is multidimensional array and it has values with column name.

# %%
a = {
    "Name":['Sam','Raj','Rahul','Gaurav'],
    "Domain":['D.E','D.S','D.S','Full Stack'],
    "Duration":[30,15,45,35]
}

# %%
df = pd.DataFrame(a)
df
# Out:
#      Name      Domain  Duration
# 0     Sam         D.E        30
# 1     Raj         D.S        15
# 2   Rahul         D.S        45
# 3  Gaurav  Full Stack        35

# %%
df.to_csv("intern_student.csv")

# %%
df = pd.read_csv("/content/best_hotel.csv")

# %%
# Instant Data Scraper = Instant Data Scraper simplifies data extraction with automatic detection of tabular data and minimal clicks needed. Users can export extracted data to CSV or Excel files for further analysis and manipulation

# %%
# Polymer = Polymer AI is a platform that uses artificial intelligence to analyze data and create visualizations and dashboards, making it easier for users to understand complex information. It can be used for various purposes, including e-commerce, marketing, and general business analytics.

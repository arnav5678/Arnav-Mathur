# %%
# ML Models ------>

# Data ---- We will train the model ----> we pass input data to our model this model will return prediction of the input data.

# %%
# ML Models
# (1) Supervisied ML Model ---> When we have labelled data , then we will use this model.

# (2) UnSupervisied ML Model ----> When we have only values not included column name.

# %% [markdown]
# # **(1) Supervised ML Models**

# %%
# (1) Linerregression -----> When we have target data as Numerical(Continuous).

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("insurance.csv")

# %%
df.head(3)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523
# 2   28    male  33.00         3     no  southeast   4449.4620

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df = pd.get_dummies(df,columns = ['sex','smoker','region'])

# %%
df = df.astype(int)

# %%
df.head(3)
# Out:
#    age  bmi  children  charges  sex_female  sex_male  smoker_no  smoker_yes  \
# 0   19   27         0    16884           1         0          0           1
# 1   18   33         1     1725           0         1          1           0
# 2   28   33         3     4449           0         1          1           0
#
#    region_northeast  region_northwest  region_southeast  region_southwest
# 0                 0                 0                 0                 1
# 1                 0                 0                 1                 0
# 2                 0                 0                 1                 0

# %%
x = df.drop(columns = ['charges']) ### Input Feature

y= df['charges'] ### Target Features

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()   ### this is a model and we use when we have numerical target data.

# %%
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)
# y_pred

# %%
# y_test

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test , y_pred)
# Out:
# 0.7837888448800692

# %%
# 2+2 = 4
# 3+2 = 5
# 6+5 = 11

# 15+5 ????Actual (20) , Predict(23)

# %%
df = pd.read_csv("covid_toy.csv")

# %%
df = df.dropna()

# %%
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
df = pd.get_dummies(df,  columns = ['gender' , 'cough' , 'city'])

# %%
df.head(2)
# Out:
#    age  fever has_covid  gender_Female  gender_Male  cough_Mild  cough_Strong  \
# 0   60  103.0        No          False         True        True         False
# 1   27  100.0       Yes          False         True        True         False
#
#    city_Bangalore  city_Delhi  city_Kolkata  city_Mumbai
# 0           False       False          True        False
# 1           False        True         False        False

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=  LabelEncoder()

# %%
df['has_covid'] = lb.fit_transform(df['has_covid'])

# %%
x = df.drop(columns = ['has_covid'])
y = df['has_covid']

# %%
x_train, x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train , y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.3333333333333333
